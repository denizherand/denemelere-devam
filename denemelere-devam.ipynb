# %% [markdown]
# <a href="https://www.kaggle.com/code/denizherand/denemelere-devam?scriptVersionId=194320210" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# İlk hafta devam

# %%
y = 3.2
type(3.2)
# Out:
# float
